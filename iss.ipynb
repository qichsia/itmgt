# %%
import matplotlib.pyplot as plt
import time

timestamps = []
longitudes = []
latitudes = []

for record in range(100):
    
    data = []
    res = requests.get('http://api.open-notify.org/iss-now.json')
    json_data = res.json()
    
    # Data Points
    data.append(json_data['timestamp'])
    data.append(float(json_data['iss_position']['longitude']))
    data.append(float(json_data['iss_position']['latitude']))
    print(data)
    
    # Path of ISS
    timestamps.append(json_data['timestamp'])
    longitudes.append(float(json_data['iss_position']['longitude']))
    latitudes.append(float(json_data['iss_position']['latitude']))
    
    time.sleep(10)
    
plt.plot(longitudes, latitudes, '-o')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()
# Out:
# [1689052631, 170.2528, -33.0375]
# [1689052642, 170.8047, -32.5801]
# [1689052653, 171.3505, -32.1199]
# [1689052663, 171.8904, -31.657]
# [1689052673, 172.3991, -31.2137]
# [1689052684, 172.9278, -30.7456]
# [1689052694, 173.451, -30.2751]
# [1689052705, 173.9688, -29.8021]
# [1689052715, 174.4569, -29.3494]
# [1689052725, 174.9644, -28.8719]
# [1689052736, 175.4668, -28.3922]
# [1689052746, 175.9644, -27.9102]
# [1689052757, 176.4571, -27.4262]
# [1689052767, 176.922, -26.9633]
# [1689052777, 177.4057, -26.4752]
# [1689052788, 177.8848, -25.9854]
# [1689052798, 178.3597, -25.4936]
# [1689052809, 178.8302, -25.0]
# [1689052819, 179.2968, -24.5046]
# [1689052830, 179.7593, -24.0074]
# [1689052840, -179.7822, -23.5087]
# [1689052850, -179.349, -23.0322]
# [1689052861, -178.8977, -22.5303]
# [1689052871, -178.45, -22.0269]
# [1689052882, -178.0058, -21.5221]
# [1689052892, -177.5859, -21.0399]
# [1689052902, -177.1482, -20.5323]
# [1689052913, -176.7136, -20.0233]
# [1689052923, -176.2822, -19.5131]
# [1689052933, -175.874, -19.026]
# [1689052944, -175.4483, -18.5134]
# [1689052954, -175.0254, -17.9995]
# [1689052965, -174.6052, -17.4845]
# [1689052975, -174.2074, -16.9931]
# [1689052986, -173.7923, -16.4761]
# [1689052996, -173.3796, -15.9581]
# [1689053007, -172.9692, -15.4391]
# [1689053017, -172.5611, -14.9192]
# [1689053027, -172.1745, -14.4233]
# [1689053038, -171.7706, -13.9017]
# [1689053048, -171.3686, -13.3792]
# [1689053059, -170.9686, -12.8559]
# [1689053069, -170.5893, -12.3569]
# [1689053079, -170.1929, -11.8322]
# [1689053090, -169.798, -11.3067]
# [1689053100, -169.4047, -10.7807]
# [1689053110, -169.0317, -10.2791]
# [1689053121, -168.6414, -9.7519]
# [1689053131, -168.2525, -9.2241]
# [1689053141, -167.8832, -8.721]
# [1689053152, -167.4968, -8.1923]
# [1689053162, -167.1114, -7.663]
# [1689053173, -166.7271, -7.1333]
# [1689053183, -166.3437, -6.6031]
# [1689053193, -165.9794, -6.0979]
# [1689053204, -165.5978, -5.5671]
# [1689053214, -165.2169, -5.036]
# [1689053225, -164.8186, -4.4792]
# [1689053235, -164.4571, -3.9728]
# [1689053246, -164.078, -3.4408]
# [1689053256, -163.6993, -2.9086]
# [1689053267, -163.3211, -2.3764]
# [1689053277, -162.9612, -1.8693]
# [1689053287, -162.5836, -1.3368]
